# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# 1️⃣ Load Iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# 2️⃣ Display first 5 rows
print("First 5 rows of Iris dataset:")
print(df.head())

# 3️⃣ Dataset info
print("\nDataset info:")
print(df.info())

# 4️⃣ Summary statistics
print("\nSummary statistics:")
print(df.describe())

# 5️⃣ Check for missing values
print("\nMissing values in each column:")
print(df.isnull().sum())

# --------------------------
# Individual feature plots
# --------------------------

# Histogram for sepal length
plt.figure(figsize=(6,4))
plt.hist(df['sepal length (cm)'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.show()

# Histogram for sepal width
plt.figure(figsize=(6,4))
plt.hist(df['sepal width (cm)'], bins=10, color='lightgreen', edgecolor='black')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Width')
plt.show()

# Bar chart: Count of each species
plt.figure(figsize=(6,4))
df['species'].value_counts().plot(kind='bar', color=['lightblue','lightgreen','salmon'])
plt.xlabel('Species')
plt.ylabel('Count')
plt.title('Count of Each Iris Species')
plt.show()

# Pie chart: Proportion of each species
plt.figure(figsize=(5,5))
df['species'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightblue','lightgreen','salmon'])
plt.title('Proportion of Iris Species')
plt.ylabel('')
plt.show()

# Heatmap: Correlation between features
plt.figure(figsize=(6,4))
sns.heatmap(df.iloc[:,:4].corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# First 5 rows of Iris dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
# ...
